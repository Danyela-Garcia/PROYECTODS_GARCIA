# %% [markdown]
# PROYECTO FINAL
#
# DANIELA GARCÍA

# %%
#IMPORTAMOS LIBRERIAS Y GRAFICADORES
import pandas as pd
import numpy as np 
import matplotlib as mat
import seaborn as sns

# %%
#IMPORTAMOS EL DATASET
adidas=pd.read_csv (r'C:\Users\usuario\Desktop\Dataset-Garcia\Adidas1.csv',sep=';',decimal=',')

# %% [markdown]
# HIPOTESIS

# %% [markdown]
# -Influye el territorio de mayor ventas
#
# -Las ventas del oulet son significativas en le empresa

# %%
#cantidad de datos nulos por columna
adidas.isna().sum().sort_values()
# Out:
# DETALLE                0
# Retailer ID            0
# FECHA FACTURACION      0
# State                  0
# City                   0
# Product                0
# Units Sold             0
# Total Sales            0
# BENEFICIO OPERATIVO    0
# Sales Method           0
# Price per Unit         2
# Region                 7
# dtype: int64

# %%
#OBSERVAMOS INFORMACIÓN DE NUESTRO DATASET
adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DETALLE              9648 non-null   object
#  1   Retailer ID          9648 non-null   int64
#  2   FECHA FACTURACION    9648 non-null   float64
#  3   Region               9641 non-null   object
#  4   State                9648 non-null   object
#  5   City                 9648 non-null   object
#  6   Product              9648 non-null   object
#  7   Price per Unit       9646 non-null   object
#  8   Units Sold           9648 non-null   object
#  9   Total Sales          9648 non-null   object
#  10  BENEFICIO OPERATIVO  9648 non-null   object
#  11  Sales Method         9648 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 904.6+ KB

# %%
# OBSERVAMOS QUE NUESTRO DATASET ES UN DATAFRAME
type(adidas)
# Out:
# pandas.core.frame.DataFrame

# %%
#CALCULAMOS EL MAXIMO RENDIMIENTO DE GANANCIA 
print(adidas['BENEFICIO OPERATIVO'].max())
# Out:
# $998

# %%
print(adidas['BENEFICIO OPERATIVO'].min())
# Out:
# $0

# %%
import matplotlib.pyplot as plt

# %%
adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DETALLE              9648 non-null   object
#  1   Retailer ID          9648 non-null   int64
#  2   FECHA FACTURACION    9648 non-null   float64
#  3   Region               9641 non-null   object
#  4   State                9648 non-null   object
#  5   City                 9648 non-null   object
#  6   Product              9648 non-null   object
#  7   Price per Unit       9646 non-null   object
#  8   Units Sold           9648 non-null   object
#  9   Total Sales          9648 non-null   object
#  10  BENEFICIO OPERATIVO  9648 non-null   object
#  11  Sales Method         9648 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 904.6+ KB

# %%
df=adidas

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Region'],bins=30 , kde=True)
plt.title('distribucion de ventas segun region')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['BENEFICIO OPERATIVO'],bins=30 , kde=True)
plt.title('distribucion de ventas')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Sales Method'],bins=30 , kde=True)
plt.title('ventas segun LOCALES')
plt.xlabel('')
plt.ylabel('')
plt.show()
